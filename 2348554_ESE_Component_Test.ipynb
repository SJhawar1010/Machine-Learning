# %% [markdown]
# <a href="https://colab.research.google.com/github/SJhawar1010/Machine-Learning/blob/main/2348554_ESE_Component_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

# %%
def gather_system_info():
# Begin the arcane ritual of gathering esoteric system information
# By invoking various incantations and peering into the abyss
# Commence with deciphering the enigmatic Operating System details
  mystical_os_name = os.name
  cryptic_platform = platform.system()
  cryptic_release_version = platform.release()

# %%
# Invoke the CPU spirits to reveal their mystic usage patterns
cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)
# Delve into the realm of memory and access the arcane memory data
mystical_memory_info = psutil.virtual_memory()
arcane_total_memory = mystical_memory_info.total
arcane_available_memory = mystical_memory_info.available

# %%
# Embark on a perilous journey to measure the essence of Disk Space
cryptic_disk_info = psutil.disk_usage('/')
mysterious_total_space = cryptic_disk_info.total
enigmatic_used_space = cryptic_disk_info.used
cryptic_free_space = cryptic_disk_info.free

# %%
# Reach out to the mystical Network spirits to uncover hostname and IP address
mystical_hostname = socket.gethostname()
arcane_ip_address = socket.gethostbyname(mystical_hostname)

# %%
# Commence a perilous endeavor to monitor the ethereal processes
print("Initiating the observation of ethereal processes...")
for spectral_process in psutil.process_iter(['pid', 'name']):
  spectral_pid = spectral_process.info['pid']
  spectral_name = spectral_process.info['name']
  print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")
# Out:
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 7, Spectral Name: node
# Spectral PID: 20, Spectral Name: tail
# Spectral PID: 31, Spectral Name: oom_monitor.sh
# Spectral PID: 33, Spectral Name: run.sh
# Spectral PID: 36, Spectral Name: kernel_manager_proxy
# Spectral PID: 62, Spectral Name: python3
# Spectral PID: 63, Spectral Name: colab-fileshim.
# Spectral PID: 80, Spectral Name: jupyter-noteboo
# Spectral PID: 81, Spectral Name: dap_multiplexer
# Spectral PID: 242, Spectral Name: python3
# Spectral PID: 273, Spectral Name: python3
# Spectral PID: 302, Spectral Name: language_service
# Spectral PID: 310, Spectral Name: node
# Spectral PID: 3960, Spectral Name: bash
# Spectral PID: 3961, Spectral Name: drive
# Spectral PID: 3962, Spectral Name: grep
# Spectral PID: 4053, Spectral Name: drive
# Spectral PID: 4136, Spectral Name: bash
# Spectral PID: 4137, Spectral Name: directoryprefetcher_binary
# Spectral PID: 4138, Spectral Name: tail
# Spectral PID: 4139, Spectral Name: python3
# Spectral PID: 20093, Spectral Name: python3
# Spectral PID: 24269, Spectral Name: language_service
# Spectral PID: 24275, Spectral Name: node
# Spectral PID: 24285, Spectral Name: sleep

# %%
if __name__ == '__main__':
  # Prepare the summoning circle for a separate, parallel dimension
  parallel_realm_gates = multiprocessing.Process(target=gather_system_info)
  # Open the gates and start the mysterious ritual in the background
  parallel_realm_gates.start()
  # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
  for i in range(1, 11):
    print(f"Number {i} (big size)")
    time.sleep(1)
# Out:
# Number 1 (big size)
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# Number 10 (big size)

# %%
# Obtain the current system date and time
current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"System Date and Time: {current_datetime}")
# Display the final message
print("BackGround Record Starts..ALL THE BEST…")
# Out:
# System Date and Time: 2023-10-04 10:17:07
# BackGround Record Starts..ALL THE BEST…

# %%
#Q2 Lab_Exam Starts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Machine Learning Datasets/Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data.shape
# Out:
# (150, 6)

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data.drop('Id', axis=1, inplace=True)

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
fig, ax = plt.subplots(1,4, figsize=(20,6))

sns.distplot(data.SepalLengthCm, ax=ax[0])
sns.distplot(data.SepalWidthCm, ax=ax[1])
sns.distplot(data.PetalLengthCm, ax=ax[2])
sns.distplot(data.PetalWidthCm, ax=ax[3])

fig.show()
# Out:
# <ipython-input-163-439fd9e9dedc>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.SepalLengthCm, ax=ax[0])
# <ipython-input-163-439fd9e9dedc>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.SepalWidthCm, ax=ax[1])
# <ipython-input-163-439fd9e9dedc>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.PetalLengthCm, ax=ax[2])
# <ipython-input-163-439fd9e9dedc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.PetalWidthCm, ax=ax[3])

# %%
sns.boxplot(x="Species", y="SepalLengthCm", data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.FacetGrid(data=data,hue="Species",height=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].corr(),annot=True,cmap="YlGnBu")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data, x="SepalLengthCm", hue="Species")
plt.title("Sepal length distribution")
plt.show()

# %%
sns.histplot(data, x="SepalWidthCm", hue="Species")
plt.title("Sepal length distribution")
plt.show()

# %%
sns.histplot(data, x="PetalLengthCm", hue="Species")
plt.title("Sepal length distribution")
plt.show()

# %%
sns.histplot(data, x="PetalWidthCm", hue="Species")
plt.title("Sepal length distribution")
plt.show()

# %%
sns.scatterplot(
    x="PetalLengthCm",
    y="PetalWidthCm",
    hue="Species",
    data=data,
)
plt.title("Petal Length vs. Petal Width")
plt.show()

# %%
sns.pairplot(data, hue="Species", height=2)
plt.show()

# %%
data.Species = [1 if each == "Iris-versicolor" else 0 for each in data.Species]
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
y = data.Species.values
x = data.drop(["Species"], axis=1)

x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]],
    data["Species"],
    test_size=0.30,
    random_state=42,)
print("Train Shape",X_train.shape)
print("Test Shape",X_test.shape)
# Out:
# Train Shape (105, 4)
# Test Shape (45, 4)

# %%
lrn = LogisticRegression()
lrn.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lrn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7333333333333333

# %%
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)
# Out:
# 0.5714285714285714

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)
# Out:
# 0.4

# %%
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)
# Out:
# 0.3076923076923077

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.6069711538461539

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.24791086350974934

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.2675485015731593

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), cmap='jet', annot=True)
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve
fpr, tpr, threshold = roc_curve(y_test, lrn.predict_proba(X_test)[:, -1])
plt.plot(fpr, tpr)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curve')
plt.show()

# %%
from sklearn.metrics import auc
print(f'AUC calculated by sklearn: {auc(fpr, tpr)}')
# Out:
# AUC calculated by sklearn: 0.7668269230769231

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, threshold = precision_recall_curve(y_test, lrn.predict_proba(X_test)[:, -1])

plt.plot(recall, precision)
plt.title('Precision v/s Recall')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
from sklearn.metrics import log_loss

log_loss(y_test, lrn.predict_proba(X_test)[:,-1])
# Out:
# 0.4992184995656685

# %%
x = np.arange(-10, 10, 0.01)
sigmoid = 1/(1+np.exp(-x))
plt.plot(sigmoid)
plt.title('Sigmoid Function')
plt.xlabel('f(x)')
plt.ylabel('x')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

grid={"C":np.logspace(-3,3,42),
      "penalty":["l1","l2"],
     "solver":['lbfgs', 'liblinear', 'saga', 'newton-cg']}
logreg=LogisticRegression(max_iter=200)
logreg_cv=GridSearchCV(logreg, grid, cv=10, verbose=3, scoring='neg_log_loss')
logreg_cv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 336 candidates, totalling 3360 fits
# [CV 1/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END ..C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END .C=0.001, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l1, solver=saga;, score=-0.680 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l1, solver=saga;, score=-0.663 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l1, solver=saga;, score=-0.658 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l1, solver=saga;, score=-0.665 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l1, solver=saga;, score=-0.662 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l1, solver=saga;, score=-0.673 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l1, solver=saga;, score=-0.673 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l1, solver=saga;, score=-0.640 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l1, solver=saga;, score=-0.644 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l1, solver=saga;, score=-0.646 total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.651 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.655 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.652 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.654 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.676 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.618 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l2, solver=lbfgs;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.652 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.668 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.656 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.669 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.661 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.687 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.670 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.635 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.638 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l2, solver=liblinear;, score=-0.641 total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l2, solver=saga;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l2, solver=saga;, score=-0.651 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l2, solver=saga;, score=-0.655 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l2, solver=saga;, score=-0.652 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l2, solver=saga;, score=-0.654 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l2, solver=saga;, score=-0.676 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l2, solver=saga;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l2, solver=saga;, score=-0.618 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l2, solver=saga;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.651 total time=   0.0s
# [CV 3/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.655 total time=   0.0s
# [CV 4/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.652 total time=   0.0s
# [CV 5/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.654 total time=   0.0s
# [CV 6/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.676 total time=   0.0s
# [CV 7/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.618 total time=   0.0s
# [CV 9/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.001, penalty=l2, solver=newton-cg;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.665 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.662 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.675 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.674 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.669 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.677 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.673 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.636 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.657 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l1, solver=saga;, score=-0.641 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.650 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.650 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.653 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.674 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l2, solver=lbfgs;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.649 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.665 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.652 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.666 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.658 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.687 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.669 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.629 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.633 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l2, solver=liblinear;, score=-0.635 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.650 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.650 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.653 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.674 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l2, solver=saga;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.657 total time=   0.0s
# [CV 2/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.650 total time=   0.0s
# [CV 3/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.650 total time=   0.0s
# [CV 5/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.653 total time=   0.0s
# [CV 6/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.674 total time=   0.0s
# [CV 7/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.678 total time=   0.0s
# [CV 8/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0014006881788178693, penalty=l2, solver=newton-cg;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.668 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.658 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.661 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.669 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.661 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.675 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.677 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.665 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.647 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l1, solver=saga;, score=-0.673 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.647 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.648 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.652 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.673 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.677 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l2, solver=lbfgs;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.647 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.661 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.650 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.663 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.655 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.687 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.669 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.623 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.628 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l2, solver=liblinear;, score=-0.631 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.647 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.648 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.652 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.673 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.677 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l2, solver=saga;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.647 total time=   0.0s
# [CV 3/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.654 total time=   0.0s
# [CV 4/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.648 total time=   0.0s
# [CV 5/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.652 total time=   0.0s
# [CV 6/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.673 total time=   0.0s
# [CV 7/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.677 total time=   0.0s
# [CV 8/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.617 total time=   0.0s
# [CV 9/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0019619273742801178, penalty=l2, solver=newton-cg;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.668 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.676 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.671 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.669 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.657 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.675 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.674 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.659 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.649 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l1, solver=saga;, score=-0.631 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.644 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.653 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.646 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.651 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.671 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.676 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l2, solver=lbfgs;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.645 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.657 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.647 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.660 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.653 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.686 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.668 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.618 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.625 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l2, solver=liblinear;, score=-0.627 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.644 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.653 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.646 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.651 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.671 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.676 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l2, solver=saga;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.658 total time=   0.0s
# [CV 2/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.644 total time=   0.0s
# [CV 3/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.653 total time=   0.0s
# [CV 4/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.646 total time=   0.0s
# [CV 5/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.651 total time=   0.0s
# [CV 6/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.671 total time=   0.0s
# [CV 7/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.676 total time=   0.0s
# [CV 8/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0027480484808533427, penalty=l2, solver=newton-cg;, score=-0.618 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.662 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.656 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.668 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.659 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.656 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.674 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.677 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.664 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.657 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l1, solver=saga;, score=-0.652 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.659 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.641 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.652 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.643 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.649 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.668 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.675 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l2, solver=lbfgs;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.644 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.652 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.645 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.655 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.650 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.684 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.667 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.613 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.622 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l2, solver=liblinear;, score=-0.624 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.659 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.641 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.652 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.643 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.649 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.669 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.675 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l2, solver=saga;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.659 total time=   0.0s
# [CV 2/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.641 total time=   0.0s
# [CV 3/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.652 total time=   0.0s
# [CV 4/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.643 total time=   0.0s
# [CV 5/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.649 total time=   0.0s
# [CV 6/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.668 total time=   0.0s
# [CV 7/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.675 total time=   0.0s
# [CV 8/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.616 total time=   0.0s
# [CV 9/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.0038491590219496812, penalty=l2, solver=newton-cg;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.656 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.662 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.676 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.666 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.666 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.673 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.675 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.663 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.640 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l1, solver=saga;, score=-0.623 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.660 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.636 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.651 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.639 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.647 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.666 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.674 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.614 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l2, solver=lbfgs;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.643 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.645 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.642 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.650 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.647 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.681 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.666 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.609 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.620 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l2, solver=liblinear;, score=-0.622 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.660 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.636 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.651 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.639 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.647 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.666 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.674 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.614 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l2, solver=saga;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.660 total time=   0.0s
# [CV 2/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.636 total time=   0.0s
# [CV 3/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.651 total time=   0.0s
# [CV 4/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.639 total time=   0.0s
# [CV 5/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.647 total time=   0.0s
# [CV 6/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.666 total time=   0.0s
# [CV 7/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.674 total time=   0.0s
# [CV 8/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.614 total time=   0.0s
# [CV 9/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.619 total time=   0.0s
# [CV 10/10] END C=0.005391471540435065, penalty=l2, solver=newton-cg;, score=-0.617 total time=   0.0s
# [CV 1/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 6/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 7/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 8/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 9/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 10/10] END C=0.007551770453120364, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 2/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 3/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 4/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 5/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 6/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# [CV 7/10] END C=0.007551770453120364, penalty=l1, solver=liblinear;, score=-0.693 total time=   0.0s
# ...
# [CV 6/10] END C=1000.0, penalty=l1, solver=liblinear;, score=-0.629 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l1, solver=liblinear;, score=-0.420 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l1, solver=liblinear;, score=-0.529 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l1, solver=liblinear;, score=-0.540 total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l1, solver=liblinear;, score=-0.605 total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.741 total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.401 total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.414 total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.518 total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.659 total time=   0.0s
# [CV 6/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.536 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.466 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.572 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.584 total time=   0.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 10/10] END C=1000.0, penalty=l1, solver=saga;, score=-0.477 total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.654 total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.338 total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.416 total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.504 total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.769 total time=   0.0s
# [CV 6/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.629 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.420 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.529 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.540 total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l2, solver=lbfgs;, score=-0.606 total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.656 total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.339 total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.415 total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.504 total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.766 total time=   0.0s
# [CV 6/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.628 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.421 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.529 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.541 total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l2, solver=liblinear;, score=-0.603 total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.741 total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.401 total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.414 total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.518 total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.660 total time=   0.0s
# [CV 6/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.536 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.466 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.572 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.583 total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l2, solver=saga;, score=-0.477 total time=   0.0s
# [CV 1/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.654 total time=   0.0s
# [CV 2/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.338 total time=   0.0s
# [CV 3/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.416 total time=   0.0s
# [CV 4/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.504 total time=   0.0s
# [CV 5/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.769 total time=   0.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 6/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.629 total time=   0.0s
# [CV 7/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.420 total time=   0.0s
# [CV 8/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.529 total time=   0.0s
# [CV 9/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.540 total time=   0.0s
# [CV 10/10] END C=1000.0, penalty=l2, solver=newton-cg;, score=-0.606 total time=   0.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 840 fits failed out of a total of 3360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 420 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 420 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [        nan -0.69314718 -0.66035925         nan -0.6476487  -0.65760791
#  -0.64764862 -0.64764821         nan -0.69314718 -0.66282536         nan
#  -0.64707407 -0.65433952 -0.64707453 -0.64707399         nan -0.69314718
#  -0.66535765         nan -0.6463125  -0.65137967 -0.64631233 -0.64631229
#          nan -0.69314718 -0.66291537         nan -0.64531489 -0.64854939
#  -0.64531535 -0.64531518         nan -0.69314718 -0.66238593         nan
#  -0.6440264  -0.6456401  -0.64402575 -0.64402645         nan -0.69314718
#  -0.6600188          nan -0.64237755 -0.64247286 -0.6423747  -0.64237758
#          nan -0.69314718 -0.66255832         nan -0.64027793 -0.63893793
#  -0.64026493 -0.64027857         nan -0.69314718 -0.65475343         nan
#  -0.63760355 -0.63501328 -0.63755249 -0.63760455         nan -0.68142431
#  -0.65806876         nan -0.63418428 -0.63075419 -0.63403921 -0.63418405
#          nan -0.66682553 -0.65230919         nan -0.62980093 -0.62625459
#  -0.62954686 -0.6298012          nan -0.65926993 -0.65089345         nan
#  -0.62422045 -0.62159356 -0.62384872 -0.62422047         nan -0.65535373
#  -0.65040081         nan -0.61724039 -0.61677464 -0.61717455 -0.61724092
#          nan -0.63904222 -0.64954885         nan -0.60877141 -0.61170674
#  -0.60953836 -0.6087707          nan -0.63234823 -0.64940897         nan
#  -0.59889744 -0.60623099 -0.60107152 -0.59889739         nan -0.62929787
#  -0.64095699         nan -0.58793034 -0.60018107 -0.59190779 -0.58793036
#          nan -0.61924393 -0.60223846         nan -0.5763805  -0.59347833
#  -0.58237832 -0.57638101         nan -0.61116588 -0.57773107         nan
#  -0.5648848  -0.58618207 -0.57289744 -0.56488294         nan -0.60729438
#  -0.56265616         nan -0.55408016 -0.57855209 -0.56384268 -0.55408304
#          nan -0.59248737 -0.55655454         nan -0.54454344 -0.57093626
#  -0.55566042 -0.54454314         nan -0.57961241 -0.5520955          nan
#  -0.53667273 -0.56368779 -0.54873931 -0.53667318         nan -0.57193107
#  -0.54749035         nan -0.53070641 -0.55707729 -0.54317297 -0.53070612
#          nan -0.55348843 -0.54327179         nan -0.52669018 -0.55122508
#  -0.53929568 -0.52669043         nan -0.53940134 -0.53989484         nan
#  -0.52450905 -0.54611773 -0.53671907 -0.52450736         nan -0.52995378
#  -0.5381362          nan -0.52390502 -0.54165681 -0.53537986 -0.52390457
#          nan -0.52676228 -0.53736335         nan -0.52453707 -0.53780273
#  -0.53480091 -0.52453899         nan -0.52707458 -0.53694431         nan
#  -0.5260229  -0.53457895 -0.53472404 -0.5260223          nan -0.5294077
#  -0.53678134         nan -0.52798517 -0.53205802 -0.53493779 -0.5279861
#          nan -0.53182847 -0.5367459          nan -0.53011533 -0.53044478
#  -0.53529001 -0.53011469         nan -0.53391822 -0.53673971         nan
#  -0.53217686 -0.52963814 -0.53562806 -0.53217583         nan -0.53561728
#  -0.53682379         nan -0.53402369 -0.52972027 -0.53583441 -0.53402445
#          nan -0.53689971 -0.53687842         nan -0.53559232 -0.53049029
#  -0.53611738 -0.53559021         nan -0.53792439 -0.53693553         nan
#  -0.53686063 -0.53169187 -0.53641751 -0.53686178         nan -0.53862207
#  -0.53700819         nan -0.53785906 -0.53307693 -0.53660266 -0.53785945
#          nan -0.53919473 -0.53691164         nan -0.53862449 -0.53458014
#  -0.53668442 -0.53862476         nan -0.53957175 -0.53691001         nan
#  -0.53919465 -0.53586816 -0.5367447  -0.53919932         nan -0.53989712
#  -0.53699829         nan -0.53962359 -0.53697342 -0.53684821 -0.53962512
#          nan -0.54008231 -0.53690592         nan -0.53993689 -0.53792735
#  -0.53677986 -0.53993758         nan -0.54021332 -0.53683286         nan
#  -0.54015956 -0.53867621 -0.53687022 -0.54016506         nan -0.54030906
#  -0.53699245         nan -0.54032927 -0.53918647 -0.53701073 -0.54032977
#          nan -0.54040203 -0.53703431         nan -0.54044898 -0.53960173
#  -0.53681831 -0.54044857         nan -0.5404269  -0.53698811         nan
#  -0.54053041 -0.53992792 -0.5369353  -0.54053401         nan -0.54049096
#  -0.53693525         nan -0.54059364 -0.5401559  -0.53692129 -0.54059528]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=LogisticRegression(max_iter=200),
#              param_grid={'C': array([1.00000000e-03, 1.40068818e-03, 1.96192737e-03, 2.74804848e-03,
#        3.84915902e-03, 5.39147154e-03, 7.55177045e-03, 1.05776756e-02,
#        1.48160252e-02, 2.07526313e-02, 2.90679654e-02, 4.07151555e-02,
#        5.70292370e-02, 7.98801781e-02, 1.11887221e-01, 1.56719108e-01,
#        2.19514602e-01, 3.07471508...
#        3.25233387e+00, 4.55550561e+00, 6.38084285e+00, 8.93757115e+00,
#        1.25187503e+01, 1.75348655e+01, 2.45608788e+01, 3.44021326e+01,
#        4.81866605e+01, 6.74944857e+01, 9.45387283e+01, 1.32419279e+02,
#        1.85478119e+02, 2.59797009e+02, 3.63894599e+02, 5.09702863e+02,
#        7.13934775e+02, 1.00000000e+03]),
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['lbfgs', 'liblinear', 'saga', 'newton-cg']},
#              scoring='neg_log_loss', verbose=3)

# %%
logreg_cv.best_params_
# Out:
# {'C': 2.3219542502889814, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
best_lr = LogisticRegression(solver='liblinear', penalty='l1', C=0.43067)
best_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.43067, penalty='l1', solver='liblinear')

# %%
log_loss(y_test, best_lr.predict_proba(X_test))
# Out:
# 0.5268469244209987

# %%
accuracy_score(y_test, best_lr.predict(X_test))
# Out:
# 0.6666666666666666

# %%
data.columns[np.argmax(np.abs(best_lr.coef_))]
# Out:
# 'SepalWidthCm'
